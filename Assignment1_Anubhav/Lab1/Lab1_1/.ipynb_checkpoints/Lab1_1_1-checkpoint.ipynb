# %%
import numpy as np
import pandas as pd

# %%
# loading the dataset

# since no columns are there in the dataset
columns = [
    "age", "workclass", "fnlwgt", "education", "education-num",
    "marital-status", "occupation", "relationship", "race", "sex",
    "capital-gain", "capital-loss", "hours-per-week", "native-country", "income"
]

train_df = pd.read_csv("FCNN_Lab1_dataset/adult.data",names = columns, sep = ', *')
test_df = pd.read_csv('FCNN_Lab1_dataset/adult.test', names=columns, sep=', *',skiprows=1)

train_df['income'] = train_df['income'].str.replace('.', '', regex=False).str.strip()
test_df['income'] = test_df['income'].str.replace('.', '', regex=False).str.strip()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_12880\3095012978.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   train_df = pd.read_csv("FCNN_Lab1_dataset/adult.data",names = columns, sep = ', *')
# C:\Users\kumar\AppData\Local\Temp\ipykernel_12880\3095012978.py:11: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   test_df = pd.read_csv('FCNN_Lab1_dataset/adult.test', names=columns, sep=', *',skiprows=1)

# %%
#dealing with NA values, by filling with Mode

columns_with_na = train_df.columns[train_df.isnull().any()].tolist()

for col in columns_with_na:
    mode_value = train_df[col].mode()[0]
    train_df[col] = train_df[col].fillna(mode_value)
    test_df[col] = test_df[col].fillna(mode_value)

#now separating the output from the input features, in both train and test sets
#train sets
x_t_r = train_df.drop("income",axis=1)
y_t_r = train_df["income"].map({"<=50K":0, ">50K":1})

#test sets
x_te_r = test_df.drop("income",axis =1)
y_te_r = test_df["income"].map({"<=50K":0, ">50K":1})

#one hot encoding
x_train = pd.get_dummies(x_t_r)
x_test = pd.get_dummies(x_te_r)

#handling the case in which if the test set doesnt have a particular feature value the one hot encoded vector wont be aligned with the training data in whihch the particular extra feature did appear.

x_train, x_test = x_train.align(x_test,join='left', axis=1, fill_value=0) # fill in the left values as 0

# %%
#converting to np

x_train = x_train.values.astype(np.float32)
y_train = y_t_r.values.astype(np.float32).reshape(-1,1) # reshaping the 1-D vector to a 2-D vector so to calculate the loss yi for each input xi

x_test = x_test.values.astype(np.float32)
y_test = y_te_r.values.astype(np.float32).reshape(-1,1)
print(x_train.shape) # gives the number of input neurons required, here 108 are required
# Out:
# (32561, 108)

# %% [markdown]
# ## **FCNN implementation**
#
# 1. total neurons in input layer = 108
# 2. total neurons in 1st hidden layer = 65, total neurons in second hidden layer = 33
# 3. total neurons in output layer = 1
# 4. total weights in 1st layer = 108*65 = 7020 + 65 biases = 7085 in layer 1->2
# 5. total weights and biases in 2nd layer = 65*33 + 33 biases = 2178 in layer 2->3
# 6. total weights and biases in layer 3-> output = 34
# 7. total parameters to tune = 9297

# %%
def forward_pass(x,theta): # relu for hidden and sigmoid for output
    A1 = np.dot(x,theta["w1"]) + theta["b1"]
    H1 = np.maximum(0,A1) #ReLU activation

    A2 = np.dot(H1,theta["w2"]) + theta["b2"]
    H2 = np.maximum(0,A2)

    A3 = np.dot(H2,theta["w3"]) + theta["b3"]
    A3_clipped = np.clip(A3, -500, 500)
    H3 = 1 / (1 + np.exp(-A3_clipped))

    cache = {"A1":A1, "H1":H1, "A2":A2, "H2":H2, "A3":A3, "H3":H3}
    return cache

# %%
def backpropagation(x,y,cache,theta):
    # compute the derivative of loss fn wrt output unit (y_exp (is just H3) then aL), the required loss function is the cross-entropy loss
    dA3 = cache["H3"] - y
    # now we compute the grad wrt w3 and b3 (before out layer)
    m = x.shape[0]
    dw3 = (1/m)*(np.dot(cache["H2"].T,dA3))
    db3 = (1/m)*np.sum(dA3, axis=0, keepdims=True)

    dH2 = np.dot(dA3,theta["w3"].T)
    dA2 = np.array(dH2, copy=True)
    dA2[cache["A2"] <= 0] = 0 # if the contribution is less than 0 deriv is 0 other wise 1 so 1*dh2

    dw2 = (1/m)*(np.dot(cache["H1"].T,dA2))
    db2 = (1/m)*np.sum(dA2, axis=0, keepdims=True)

    dH1 = np.dot(dA2,theta["w2"].T)
    dA1 = np.array(dH1, copy=True)
    dA1[cache["A1"] <= 0] = 0

    dw1 = (1/m)*(np.dot(x.T,dA1))
    db1 = (1/m)*np.sum(dA1, axis=0, keepdims=True)

    grad = {"dw1": dw1, "db1": db1,
    "dw2": dw2, "db2": db2,
    "dw3": dw3, "db3": db3}
    return grad

# %%
def update(theta, grad, neta = 0.01):
    theta["w1"] -= neta * grad["dw1"]
    theta["b1"] -= neta * grad["db1"]
    
    theta["w2"] -= neta * grad["dw2"]
    theta["b2"] -= neta * grad["db2"]
    
    theta["w3"] -= neta * grad["dw3"]
    theta["b3"] -= neta * grad["db3"]
    
    return theta

# %%
def Loss_calc(y,H3): #calculate the cross entropy loss (as we are focusing on binary classification)
    m = y.shape[0] #total samples
    corr = 1e-8
    H3 = np.clip(H3, corr, 1 - corr) # avoiding the log(0) and log(1) cases
    
    # bin Cross entropy loss
    loss = - (1/m)*np.sum(y * np.log(H3) + 3*(1 - y)*np.log(1 - H3))
    return loss

# %%
def SGD(ep):
    # layer 1 
    w1 = np.random.randn(108,65)*np.sqrt(2/108) #He-initialization of weights
    b1 = np.zeros((1,65))
    # layer 2
    w2 = np.random.randn(65,33)*np.sqrt(2/65)
    b2 = np.zeros((1,33)) 
    # layer 3
    w3 = np.random.randn(33,1)*np.sqrt(2/33) 
    b3 = np.zeros((1,1))
    # applying the forwardPass algorithm with backprop for learning the weights
    theta = {"w1":w1, "b1":b1, "w2":w2, "b2":b2, "w3":w3, "b3":b3}
    iter = 0
    neta = 0.01
    for epoch in range(ep): # outer loop for training different epochs, to stop the network from memorising the training data
        ind = np.arange(x_train.shape[0])
        np.random.shuffle(ind)
        x_shf = x_train[ind]
        y_shf = y_train[ind]
        # inner loop for minibatch grad descent
        for i in range(0,x_shf.shape[0],128):
            x_b = x_shf[i:i+128]
            y_b = y_shf[i:i+128]

            cache = forward_pass(x_b,theta) #cache is the activations + pre-activations
            grad = backpropagation(x_b, y_b, cache, theta)
            theta = update(theta,grad,neta)
            if iter%100 == 0:
            # Calculate current loss on the current batch
                current_loss = Loss_calc(y_b, cache['H3'])
                print(f"Iteration {iter} | Loss: {current_loss:.3f}")
            iter+=1
    return theta

# %%
# main

theta = SGD(50)
def evaluate_metrics(x_test, y_test, theta):
    # 1. Get predictions
    cache = forward_pass(x_test, theta)
    # Convert probabilities to binary 0 or 1
    predictions = (cache["H3"] > 0.5).astype(int)
    
    # 2. Basic Accuracy
    accuracy = np.mean(predictions == y_test) * 100
    
    # 3. Calculate components for advanced metrics
    # True Positives: Predicted >50K and actually >50K
    tp = np.sum((predictions == 1) & (y_test == 1))
    # True Negatives: Predicted <=50K and actually <=50K
    tn = np.sum((predictions == 0) & (y_test == 0))
    # False Positives: Predicted >50K but actually <=50K
    fp = np.sum((predictions == 1) & (y_test == 0))
    # False Negatives: Predicted <=50K but actually >50K
    fn = np.sum((predictions == 0) & (y_test == 1))
    
    # 4. Precision, Recall, and F1
    # We add a tiny epsilon to denominators to avoid division by zero
    precision = tp / (tp + fp + 1e-15) 
    recall = tp / (tp + fn + 1e-15)
    f1_score = 2 * (precision * recall) / (precision + recall + 1e-15)
    
    # Print a clean report
    print("--- Model Performance Report ---")
    print(f"Accuracy:  {accuracy:.2f}%")
    print(f"Precision: {precision:.4f} (How many predicted high-earners actually are)")
    print(f"Recall:    {recall:.4f} (How many actual high-earners were caught)")
    print(f"F1-Score:  {f1_score:.4f} (Balanced harmonic mean)")
    print("--------------------------------")
    
    return {"acc": accuracy, "p": precision, "r": recall, "f1": f1_score}

# Usage:
results = evaluate_metrics(x_test, y_test, theta)
# Out:
# Iteration 0 | Loss: 5.181
# Iteration 100 | Loss: 1.506
# Iteration 200 | Loss: 1.401
# Iteration 300 | Loss: 1.283
# Iteration 400 | Loss: 1.203
# Iteration 500 | Loss: 1.154
# Iteration 600 | Loss: 1.117
# Iteration 700 | Loss: 1.094
# Iteration 800 | Loss: 1.050
# Iteration 900 | Loss: 1.060
# Iteration 1000 | Loss: 1.046
# Iteration 1100 | Loss: 1.006
# Iteration 1200 | Loss: 0.981
# Iteration 1300 | Loss: 1.005
# Iteration 1400 | Loss: 0.994
# Iteration 1500 | Loss: 0.985
# Iteration 1600 | Loss: 0.957
# Iteration 1700 | Loss: 1.002
# Iteration 1800 | Loss: 0.992
# Iteration 1900 | Loss: 0.956
# Iteration 2000 | Loss: 0.971
# Iteration 2100 | Loss: 0.987
# Iteration 2200 | Loss: 0.980
# Iteration 2300 | Loss: 0.958
# Iteration 2400 | Loss: 0.920
# Iteration 2500 | Loss: 0.984
# Iteration 2600 | Loss: 0.964
# Iteration 2700 | Loss: 0.927
# Iteration 2800 | Loss: 0.960
# Iteration 2900 | Loss: 0.988
# Iteration 3000 | Loss: 0.950
# Iteration 3100 | Loss: 0.966
# Iteration 3200 | Loss: 0.949
# Iteration 3300 | Loss: 1.000
# Iteration 3400 | Loss: 1.004
# Iteration 3500 | Loss: 0.958
# Iteration 3600 | Loss: 1.000
# Iteration 3700 | Loss: 0.948
# Iteration 3800 | Loss: 1.005
# Iteration 3900 | Loss: 0.970
# Iteration 4000 | Loss: 0.949
# Iteration 4100 | Loss: 0.981
# Iteration 4200 | Loss: 1.004
# Iteration 4300 | Loss: 0.977
# Iteration 4400 | Loss: 0.963
# Iteration 4500 | Loss: 0.971
# Iteration 4600 | Loss: 0.943
# Iteration 4700 | Loss: 0.995
# Iteration 4800 | Loss: 0.971
# Iteration 4900 | Loss: 0.967
# Iteration 5000 | Loss: 0.972
# Iteration 5100 | Loss: 0.957
# Iteration 5200 | Loss: 0.994
# Iteration 5300 | Loss: 0.952
# Iteration 5400 | Loss: 0.949
# Iteration 5500 | Loss: 0.975
# Iteration 5600 | Loss: 0.961
# Iteration 5700 | Loss: 0.962
# Iteration 5800 | Loss: 0.958
# Iteration 5900 | Loss: 0.985
# Iteration 6000 | Loss: 0.959
# Iteration 6100 | Loss: 0.930
# Iteration 6200 | Loss: 0.999
# Iteration 6300 | Loss: 1.000
# Iteration 6400 | Loss: 0.966
# Iteration 6500 | Loss: 0.972
# Iteration 6600 | Loss: 0.962
# Iteration 6700 | Loss: 0.985
# Iteration 6800 | Loss: 1.012
# Iteration 6900 | Loss: 0.994
# Iteration 7000 | Loss: 0.994
# Iteration 7100 | Loss: 0.981
# Iteration 7200 | Loss: 0.972
# Iteration 7300 | Loss: 0.962
# Iteration 7400 | Loss: 0.985
# Iteration 7500 | Loss: 0.981
# Iteration 7600 | Loss: 1.013
# Iteration 7700 | Loss: 0.975
# Iteration 7800 | Loss: 0.979
# Iteration 7900 | Loss: 0.985
# Iteration 8000 | Loss: 0.985
# Iteration 8100 | Loss: 0.977
# Iteration 8200 | Loss: 0.986
# Iteration 8300 | Loss: 0.961
# Iteration 8400 | Loss: 0.995
# Iteration 8500 | Loss: 0.968
# Iteration 8600 | Loss: 0.949
# Iteration 8700 | Loss: 0.956
# Iteration 8800 | Loss: 0.952
# Iteration 8900 | Loss: 0.967
# Iteration 9000 | Loss: 0.949
# Iteration 9100 | Loss: 0.947
# Iteration 9200 | Loss: 1.009
# Iteration 9300 | Loss: 0.941
# Iteration 9400 | Loss: 0.967
# Iteration 9500 | Loss: 0.986
# Iteration 9600 | Loss: 0.940
# Iteration 9700 | Loss: 0.966
# Iteration 9800 | Loss: 0.975
# Iteration 9900 | Loss: 0.990
# Iteration 10000 | Loss: 0.980
# Iteration 10100 | Loss: 0.942
# Iteration 10200 | Loss: 0.957
# Iteration 10300 | Loss: 1.017
# Iteration 10400 | Loss: 0.981
# Iteration 10500 | Loss: 0.994
# Iteration 10600 | Loss: 0.950
# Iteration 10700 | Loss: 0.952
# Iteration 10800 | Loss: 0.948
# Iteration 10900 | Loss: 0.953
# Iteration 11000 | Loss: 0.935
# Iteration 11100 | Loss: 0.963
# Iteration 11200 | Loss: 0.943
# Iteration 11300 | Loss: 0.968
# Iteration 11400 | Loss: 1.013
# Iteration 11500 | Loss: 0.967
# Iteration 11600 | Loss: 0.999
# Iteration 11700 | Loss: 0.953
# Iteration 11800 | Loss: 0.928
# Iteration 11900 | Loss: 0.945
# Iteration 12000 | Loss: 1.018
# Iteration 12100 | Loss: 0.963
# Iteration 12200 | Loss: 0.975
# Iteration 12300 | Loss: 0.980
# Iteration 12400 | Loss: 0.975
# Iteration 12500 | Loss: 0.953
# Iteration 12600 | Loss: 0.955
# Iteration 12700 | Loss: 0.971
# --- Model Performance Report ---
# Accuracy:  76.38%
# Precision: 0.0000 (How many predicted high-earners actually are)
# Recall:    0.0000 (How many actual high-earners were caught)
# F1-Score:  0.0000 (Balanced harmonic mean)
# --------------------------------

# %%
def min_max_scaling(df):
    # Identify numerical columns (exclude one-hot encoded ones)
    num_cols = ["age", "fnlwgt", "education-num", "capital-gain", "capital-loss", "hours-per-week"]
    
    # Apply Min-Max formula: (x - min) / (max - min) 
    for col in num_cols:
        col_min = df[col].min()
        col_max = df[col].max()
        df[col] = (df[col] - col_min) / (col_max - col_min)
    return df

x_t_r_scaled = min_max_scaling(x_t_r.copy())
x_te_r_scaled = min_max_scaling(x_te_r.copy())

x_train_scaled = pd.get_dummies(x_t_r_scaled)
x_test_scaled = pd.get_dummies(x_te_r_scaled)
x_train_scaled, x_test_scaled = x_train_scaled.align(x_test_scaled, join='left', axis=1, fill_value=0)

x_train = x_train_scaled.values.astype(np.float32)
x_test = x_test_scaled.values.astype(np.float32)
theta_scaled = SGD(50)

print("--- Results with Min-Max Scaling ---")
evaluate_metrics(x_test, y_test, theta_scaled)
# Out:
# Iteration 0 | Loss: 1.843
# Iteration 100 | Loss: 1.193
# Iteration 200 | Loss: 1.067
# Iteration 300 | Loss: 0.933
# Iteration 400 | Loss: 0.948
# Iteration 500 | Loss: 0.882
# Iteration 600 | Loss: 0.884
# Iteration 700 | Loss: 0.796
# Iteration 800 | Loss: 0.818
# Iteration 900 | Loss: 0.699
# Iteration 1000 | Loss: 0.693
# Iteration 1100 | Loss: 0.662
# Iteration 1200 | Loss: 0.681
# Iteration 1300 | Loss: 0.743
# Iteration 1400 | Loss: 0.668
# Iteration 1500 | Loss: 0.699
# Iteration 1600 | Loss: 0.696
# Iteration 1700 | Loss: 0.711
# Iteration 1800 | Loss: 0.710
# Iteration 1900 | Loss: 0.596
# Iteration 2000 | Loss: 0.717
# Iteration 2100 | Loss: 0.707
# Iteration 2200 | Loss: 0.759
# Iteration 2300 | Loss: 0.675
# Iteration 2400 | Loss: 0.793
# Iteration 2500 | Loss: 0.770
# Iteration 2600 | Loss: 0.610
# Iteration 2700 | Loss: 0.656
# Iteration 2800 | Loss: 0.650
# Iteration 2900 | Loss: 0.728
# Iteration 3000 | Loss: 0.660
# Iteration 3100 | Loss: 0.760
# Iteration 3200 | Loss: 0.654
# Iteration 3300 | Loss: 0.641
# Iteration 3400 | Loss: 0.752
# Iteration 3500 | Loss: 0.726
# Iteration 3600 | Loss: 0.837
# Iteration 3700 | Loss: 0.623
# Iteration 3800 | Loss: 0.733
# Iteration 3900 | Loss: 0.679
# Iteration 4000 | Loss: 0.585
# Iteration 4100 | Loss: 0.824
# Iteration 4200 | Loss: 0.569
# Iteration 4300 | Loss: 0.754
# Iteration 4400 | Loss: 0.640
# Iteration 4500 | Loss: 0.683
# Iteration 4600 | Loss: 0.698
# Iteration 4700 | Loss: 0.694
# Iteration 4800 | Loss: 0.702
# Iteration 4900 | Loss: 0.766
# Iteration 5000 | Loss: 0.730
# Iteration 5100 | Loss: 0.592
# Iteration 5200 | Loss: 0.734
# Iteration 5300 | Loss: 0.771
# Iteration 5400 | Loss: 0.668
# Iteration 5500 | Loss: 0.609
# Iteration 5600 | Loss: 0.670
# Iteration 5700 | Loss: 0.575
# Iteration 5800 | Loss: 0.574
# Iteration 5900 | Loss: 0.662
# Iteration 6000 | Loss: 0.647
# Iteration 6100 | Loss: 0.622
# Iteration 6200 | Loss: 0.548
# Iteration 6300 | Loss: 0.606
# Iteration 6400 | Loss: 0.701
# Iteration 6500 | Loss: 0.743
# Iteration 6600 | Loss: 0.468
# Iteration 6700 | Loss: 0.608
# Iteration 6800 | Loss: 0.686
# Iteration 6900 | Loss: 0.595
# Iteration 7000 | Loss: 0.619
# Iteration 7100 | Loss: 0.566
# Iteration 7200 | Loss: 0.647
# Iteration 7300 | Loss: 0.542
# Iteration 7400 | Loss: 0.765
# Iteration 7500 | Loss: 0.505
# Iteration 7600 | Loss: 0.775
# Iteration 7700 | Loss: 0.716
# Iteration 7800 | Loss: 0.651
# Iteration 7900 | Loss: 0.672
# Iteration 8000 | Loss: 0.645
# Iteration 8100 | Loss: 0.567
# Iteration 8200 | Loss: 0.654
# Iteration 8300 | Loss: 0.511
# Iteration 8400 | Loss: 0.572
# Iteration 8500 | Loss: 0.653
# Iteration 8600 | Loss: 0.644
# Iteration 8700 | Loss: 0.569
# Iteration 8800 | Loss: 0.612
# Iteration 8900 | Loss: 0.609
# Iteration 9000 | Loss: 0.464
# Iteration 9100 | Loss: 0.583
# Iteration 9200 | Loss: 0.641
# Iteration 9300 | Loss: 0.608
# Iteration 9400 | Loss: 0.539
# Iteration 9500 | Loss: 0.663
# Iteration 9600 | Loss: 0.670
# Iteration 9700 | Loss: 0.585
# Iteration 9800 | Loss: 0.743
# Iteration 9900 | Loss: 0.655
# Iteration 10000 | Loss: 0.523
# Iteration 10100 | Loss: 0.504
# Iteration 10200 | Loss: 0.667
# Iteration 10300 | Loss: 0.726
# Iteration 10400 | Loss: 0.604
# Iteration 10500 | Loss: 0.685
# Iteration 10600 | Loss: 0.565
# Iteration 10700 | Loss: 0.663
# Iteration 10800 | Loss: 0.707
# Iteration 10900 | Loss: 0.600
# Iteration 11000 | Loss: 0.625
# Iteration 11100 | Loss: 0.630
# Iteration 11200 | Loss: 0.488
# Iteration 11300 | Loss: 0.537
# Iteration 11400 | Loss: 0.634
# Iteration 11500 | Loss: 0.598
# Iteration 11600 | Loss: 0.667
# Iteration 11700 | Loss: 0.622
# Iteration 11800 | Loss: 0.722
# Iteration 11900 | Loss: 0.612
# Iteration 12000 | Loss: 0.578
# Iteration 12100 | Loss: 0.786
# Iteration 12200 | Loss: 0.722
# Iteration 12300 | Loss: 0.627
# Iteration 12400 | Loss: 0.651
# Iteration 12500 | Loss: 0.636
# Iteration 12600 | Loss: 0.527
# Iteration 12700 | Loss: 0.735
# --- Results with Min-Max Scaling ---
# --- Model Performance Report ---
# Accuracy:  84.21%
# Precision: 0.7083 (How many predicted high-earners actually are)
# Recall:    0.5637 (How many actual high-earners were caught)
# F1-Score:  0.6278 (Balanced harmonic mean)
# --------------------------------
# {'acc': 84.20858669614888,
#  'p': 0.7082652727866711,
#  'r': 0.5637025481019241,
#  'f1': 0.627768930070942}
